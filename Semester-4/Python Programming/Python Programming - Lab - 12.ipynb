# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
#     <center><b><h1>Karan Sonagara - 24010101694</b></center>
# <center><b><h1>Lab - 12</b></center>
# <pre>

# %%
#import matplotlib below
import matplotlib.pyplot as plt
import random

# %%
x = range(1,11)
y = [1,5,9,7,5,6,3,2,4,9]
plt.plot(x,y)
plt.show()

# write a code to display the line chart of above x & y

# %%
# write a code to display two lines in a line chart (data given above)

cxMarks = [5,8,9,6,3,2,7,8,8,9]
cyMarks = [8,9,6,3,5,7,4,1,2,6]
plt.plot(cxMarks,marker='o', lw=2.5, ls =':', label='CX Marks', c="r")
plt.plot(cyMarks, marker='s', ls ="--", lw=2.5 ,label='CY Marks', c="b")
plt.xlabel('Index')
plt.ylabel('Marks')
plt.title('Line Chart of CX and CY Marks')
plt.legend()
plt.grid(True)
plt.show()

# %%
x = range(1,11,1)
cxMarks= [8,9,6,3,5,7,4,1,2,6]
cyMarks= [5,8,9,6,3,2,4,8,8,9]
plt.plot(cxMarks)
plt.plot(cyMarks)
plt.plot(x)
plt.show()
# write a code to generate below graph

# %% [markdown]
# ### 04) WAP to demonstrate the use of Pie chart.

# %%
age = ["Karan","Ankit","Nikhil","Mahesh","Guarav","Bhavya"]
x = [8,9,6,3,5,7]
ab = ["r","b","m","g","c","w"]
plt.pie(x, labels = age, colors = ab ,radius=0.6)
plt.title("Department wise contribution",fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# ### 05) WAP to demonstrate the use of Bar chart.

# %%
name = ["Karan", "Vivek", "Gaurav", "Bhavya"]
visiters = [11000, 12000, 15000, 12500]
plt.bar(name, visiters, width=0.3)
plt.show()

# %% [markdown]
# ### 06) WAP to demonstrate the use of Scatter Plot.

# %%
random.seed(10)
x = [random.random() for i in range(100)]
y = [random.random() for i in range(100)]
z = [random.random() for i in range(100)]
plt.scatter(x,y, c=z,cmap="plasma")
plt.colorbar()
plt.show()

# %% [markdown]
# ### 07) WAP to demonstrate the use of Histogram.

# %%
random.seed(10)
age = [random.randint(0,50) for i in range(0,20)]
plt.hist(age, edgecolor="r", bins=[1,10,21,31,41,51],histtype="stepfilled", color="y")
plt.savefig("Demo.jpg")

++ab++++++++++++++++++++++++++++++++++++++++++++++
plt.show()

# %% [markdown]
# ### 08) WAP to display the value of each bar in a bar chart using Matplotlib.

# %%
name = ["Karan", "Vivek", "Gaurav", "Bhavya"]
visiters = [11000, 12000, 15000, 12500]
bars = plt.bar(name, visiters, width=0.3)
for i in bars:
    yc = i.get_height()
    plt.text(i.get_x(), yc+100, f"{yc}")
plt.show3.5

# %% [markdown]
# ### 09) WAP create a Scatter Plot with several colors in Matplotlib?

# %%
random.seed(10)
x = [random.random() for i in range(100)]
y = [random.random() for i in range(100)]
z = [random.random() for i in range(100)]
plt.scatter(x,y, c=z)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 10) WAP to create a Box Plot.

# %%
random.seed(10)
time = [ random.randint(20,120) for i in range(100)]
plt.boxplot(time, vert=False)
plt.show()
